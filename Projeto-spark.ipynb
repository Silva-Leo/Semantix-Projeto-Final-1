# %%
import pyspark as spark
from pyspark.sql.functions import *

spark = SparkSession\
.builder\
.appName('Projeto final Básico - Campanha Nacional de Vacinação contra Covid-19')\
.config('spark.some.config.option', 'some-value')\
.enableHiveSupport()\
.getOrCreate()

# %% [markdown]
# #### Investiguei um dos arquivos CSV para entender como ele está formatado. Defini para esse projeto dois arquivos csv.
# > O arquivo parte 1 encobre dados do primeiro semestre de 2021 e o arquivo parte 2 encobre dados dos primeiros 6 dias do mês de julho de 2021.

# %%
# !hdfs dfs -cat /user/leo-silva/Documentos/Semantix/spark/projeto_final/HIST_PAINEL_COVIDBR_2021_Parte1_06jul2021.csv

# %%
# !hdfs dfs -cat /user/leo-silva/Documentos/Semantix/spark/projeto_final/HIST_PAINEL_COVIDBR_2021_Parte2_06jul2021.csv

# %% [markdown]
# #### Identificado o formato do arquivo, criei o dataframe através do diretório do hdfs. Visualizei como está Schema. (Início dos tratamento dos dados).

# %%
csv_df = spark.read.csv('hdfs://namenode/user/spark/projeto_final_basico', sep=";",header=True, inferSchema=True, ignoreLeadingWhiteSpace=True, ignoreTrailingWhiteSpace=True)
csv_df.show(10, vertical=True)
# Out:
# -RECORD 0-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-01 00:00:00
#  semanaEpi              | 53
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7700578
#  casosNovos             | 24605
#  obitosAcumulado        | 195411
#  obitosNovos            | 462
#  Recuperadosnovos       | 6756284
#  emAcompanhamentoNovos  | 748883
#  interior/metropolitana | null
# -RECORD 1-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-02 00:00:00
#  semanaEpi              | 53
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7716405
#  casosNovos             | 15827
#  obitosAcumulado        | 195725
#  obitosNovos            | 314
#  Recuperadosnovos       | 6769420
#  emAcompanhamentoNovos  | 751260
#  interior/metropolitana | null
# -RECORD 2-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-03 00:00:00
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7733746
#  casosNovos             | 17341
#  obitosAcumulado        | 196018
#  obitosNovos            | 293
#  Recuperadosnovos       | 6813008
#  emAcompanhamentoNovos  | 724720
#  interior/metropolitana | null
# -RECORD 3-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-04 00:00:00
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7753752
#  casosNovos             | 20006
#  obitosAcumulado        | 196561
#  obitosNovos            | 543
#  Recuperadosnovos       | 6875230
#  emAcompanhamentoNovos  | 681961
#  interior/metropolitana | null
# -RECORD 4-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-05 00:00:00
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7810400
#  casosNovos             | 56648
#  obitosAcumulado        | 197732
#  obitosNovos            | 1171
#  Recuperadosnovos       | 6963407
#  emAcompanhamentoNovos  | 649261
#  interior/metropolitana | null
# -RECORD 5-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-06 00:00:00
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7873830
#  casosNovos             | 63430
#  obitosAcumulado        | 198974
#  obitosNovos            | 1242
#  Recuperadosnovos       | 7036530
#  emAcompanhamentoNovos  | 638326
#  interior/metropolitana | null
# -RECORD 6-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-07 00:00:00
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7961673
#  casosNovos             | 87843
#  obitosAcumulado        | 200498
#  obitosNovos            | 1524
#  Recuperadosnovos       | 7096931
#  emAcompanhamentoNovos  | 664244
#  interior/metropolitana | null
# -RECORD 7-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-08 00:00:00
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 8013708
#  casosNovos             | 52035
#  obitosAcumulado        | 201460
#  obitosNovos            | 962
#  Recuperadosnovos       | 7114474
#  emAcompanhamentoNovos  | 697774
#  interior/metropolitana | null
# -RECORD 8-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-09 00:00:00
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 8075998
#  casosNovos             | 62290
#  obitosAcumulado        | 202631
#  obitosNovos            | 1171
#  Recuperadosnovos       | 7144011
#  emAcompanhamentoNovos  | 729356
#  interior/metropolitana | null
# -RECORD 9-------------------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-10 00:00:00
#  semanaEpi              | 2
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 8105790
#  casosNovos             | 29792
#  obitosAcumulado        | 203100
#  obitosNovos            | 469
#  Recuperadosnovos       | 7167651
#  emAcompanhamentoNovos  | 735039
#  interior/metropolitana | null
# only showing top 10 rows

# %%
csv_df.printSchema()
# Out:
# root
#  |-- regiao: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- municipio: string (nullable = true)
#  |-- coduf: integer (nullable = true)
#  |-- codmun: integer (nullable = true)
#  |-- codRegiaoSaude: integer (nullable = true)
#  |-- nomeRegiaoSaude: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- semanaEpi: integer (nullable = true)
#  |-- populacaoTCU2019: integer (nullable = true)
#  |-- casosAcumulado: decimal(10,0) (nullable = true)
#  |-- casosNovos: integer (nullable = true)
#  |-- obitosAcumulado: integer (nullable = true)
#  |-- obitosNovos: integer (nullable = true)
#  |-- Recuperadosnovos: integer (nullable = true)
#  |-- emAcompanhamentoNovos: integer (nullable = true)
#  |-- interior/metropolitana: integer (nullable = true)

# %%
csv_df_to_unix = csv_df.withColumn('data', from_unixtime(unix_timestamp(csv_df.data), 'yyyy-MM-dd'))

# %%
csv_df_to_unix.show(30, vertical=True)
# Out:
# -RECORD 0----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-01
#  semanaEpi              | 53
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7700578
#  casosNovos             | 24605
#  obitosAcumulado        | 195411
#  obitosNovos            | 462
#  Recuperadosnovos       | 6756284
#  emAcompanhamentoNovos  | 748883
#  interior/metropolitana | null
# -RECORD 1----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-02
#  semanaEpi              | 53
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7716405
#  casosNovos             | 15827
#  obitosAcumulado        | 195725
#  obitosNovos            | 314
#  Recuperadosnovos       | 6769420
#  emAcompanhamentoNovos  | 751260
#  interior/metropolitana | null
# -RECORD 2----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-03
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7733746
#  casosNovos             | 17341
#  obitosAcumulado        | 196018
#  obitosNovos            | 293
#  Recuperadosnovos       | 6813008
#  emAcompanhamentoNovos  | 724720
#  interior/metropolitana | null
# -RECORD 3----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-04
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7753752
#  casosNovos             | 20006
#  obitosAcumulado        | 196561
#  obitosNovos            | 543
#  Recuperadosnovos       | 6875230
#  emAcompanhamentoNovos  | 681961
#  interior/metropolitana | null
# -RECORD 4----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-05
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7810400
#  casosNovos             | 56648
#  obitosAcumulado        | 197732
#  obitosNovos            | 1171
#  Recuperadosnovos       | 6963407
#  emAcompanhamentoNovos  | 649261
#  interior/metropolitana | null
# -RECORD 5----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-06
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7873830
#  casosNovos             | 63430
#  obitosAcumulado        | 198974
#  obitosNovos            | 1242
#  Recuperadosnovos       | 7036530
#  emAcompanhamentoNovos  | 638326
#  interior/metropolitana | null
# -RECORD 6----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  municipio              | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 9118513
#  casosNovos             | 59826
#  obitosAcumulado        | 222666
#  obitosNovos            | 1119
#  Recuperadosnovos       | 7960643
#  emAcompanhamentoNovos  | 935204
#  interior/metropolitana | null
# only showing top 30 rows

# %% [markdown]
# #### Criei o Banco de dados "covid" e particionei por Municipio ( como pede o exercício )

# %%
spark.sql("create database covid")

# %%
csv_df_to_unix.write.mode('overwrite').partitionBy('municipio').format('csv').saveAsTable('covid.municipio', path='hdfs://namenode:8020/user/hive/warehouse/covid_municipio/')

# %%
# !hdfs dfs -ls /user/hive/warehouse/covid_municipio

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +------------+
# |databaseName|
# +------------+
# |       covid|
# |     default|
# +------------+

# %%
spark.sql("USE covid")
# Out:
# DataFrame[]

# %%
spark.sql("SHOW TABLES").show()
# Out:
# +--------+-----------------+-----------+
# |database|        tableName|isTemporary|
# +--------+-----------------+-----------+
# |   covid|        municipio|      false|
# |   covid|obitos_por_estado|      false|
# |   covid|obitos_por_regiao|      false|
# +--------+-----------------+-----------+

# %%
spark.sql("SELECT * FROM municipio").show(200,vertical=True)
# Out:
# -RECORD 0----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-01
#  semanaEpi              | 53
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7700578
#  casosNovos             | 24605
#  obitosAcumulado        | 195411
#  obitosNovos            | 462
#  Recuperadosnovos       | 6756284
#  emAcompanhamentoNovos  | 748883
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 1----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-02
#  semanaEpi              | 53
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7716405
#  casosNovos             | 15827
#  obitosAcumulado        | 195725
#  obitosNovos            | 314
#  Recuperadosnovos       | 6769420
#  emAcompanhamentoNovos  | 751260
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 2----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-03
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7733746
#  casosNovos             | 17341
#  obitosAcumulado        | 196018
#  obitosNovos            | 293
#  Recuperadosnovos       | 6813008
#  emAcompanhamentoNovos  | 724720
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 3----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-04
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7753752
#  casosNovos             | 20006
#  obitosAcumulado        | 196561
#  obitosNovos            | 543
#  Recuperadosnovos       | 6875230
#  emAcompanhamentoNovos  | 681961
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 4----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-05
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7810400
#  casosNovos             | 56648
#  obitosAcumulado        | 197732
#  obitosNovos            | 1171
#  Recuperadosnovos       | 6963407
#  emAcompanhamentoNovos  | 649261
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 5----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-06
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7873830
#  casosNovos             | 63430
#  obitosAcumulado        | 198974
#  obitosNovos            | 1242
#  Recuperadosnovos       | 7036530
#  emAcompanhamentoNovos  | 638326
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 6----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-07
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 7961673
#  casosNovos             | 87843
#  obitosAcumulado        | 200498
#  obitosNovos            | 1524
#  Recuperadosnovos       | 7096931
#  emAcompanhamentoNovos  | 664244
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 7----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-08
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 8013708
#  casosNovos             | 52035
#  obitosAcumulado        | 201460
#  obitosNovos            | 962
#  Recuperadosnovos       | 7114474
#  emAcompanhamentoNovos  | 697774
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 8----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-09
#  semanaEpi              | 1
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 8075998
#  casosNovos             | 62290
#  obitosAcumulado        | 202631
#  obitosNovos            | 1171
#  Recuperadosnovos       | 7144011
#  emAcompanhamentoNovos  | 729356
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 9----------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-10
#  semanaEpi              | 2
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 8105790
#  casosNovos             | 29792
#  obitosAcumulado        | 203100
#  obitosNovos            | 469
#  Recuperadosnovos       | 7167651
#  emAcompanhamentoNovos  | 735039
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 10---------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-11
#  semanaEpi              | 2
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 
------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-03-07
#  semanaEpi              | 10
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 11019344
#  casosNovos             | 80508
#  obitosAcumulado        | 265411
#  obitosNovos            | 1086
#  Recuperadosnovos       | 9757178
#  emAcompanhamentoNovos  | 996755
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 67---------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-03-08
#  semanaEpi              | 10
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 11051665
#  casosNovos             | 32321
#  obitosAcumulado        | 266398
#  obitosNovos            | 987
#  Recuperadosnovos       | 9782320
#  emAcompanhamentoNovos  | 1002947
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 68---------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-03-09
#  semanaEpi              | 10
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 11122429
#  casosNovos             | 70764
#  obitosAcumulado        | 268370
#  obitosNovos            | 1972
#  Recuperadosnovos       | 9843218
#  emAcompanhamentoNovos  | 1010841
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 69---------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-03-10
#  semanaEpi              | 10
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 11202305
#  casosNovos             | 79876
#  obitosAcumulado        | 270656
#  obitosNovos            | 2286
#  Recuperadosnovos       | 9913739
#  emAcompanhamentoNovos  | 1017910
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 70---------------------------
#  regiao                 | Brasil
#  estado                 | null
# ...
#  obitosAcumulado        | 511142
#  obitosNovos            | 2001
#  Recuperadosnovos       | 16548159
#  emAcompanhamentoNovos  | 1263459
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 177--------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-06-26
#  semanaEpi              | 25
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 18386894
#  casosNovos             | 64134
#  obitosAcumulado        | 512735
#  obitosNovos            | 1593
#  Recuperadosnovos       | 16582053
#  emAcompanhamentoNovos  | 1292106
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 178--------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-06-27
#  semanaEpi              | 26
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 18420598
#  casosNovos             | 33704
#  obitosAcumulado        | 513474
#  obitosNovos            | 739
#  Recuperadosnovos       | 16613992
#  emAcompanhamentoNovos  | 1293132
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 179--------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-06-28
#  semanaEpi              | 26
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 18448402
#  casosNovos             | 27804
#  obitosAcumulado        | 514092
#  obitosNovos            | 618
#  Recuperadosnovos       | 16673329
#  emAcompanhamentoNovos  | 1260981
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 180--------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-06-29
#  semanaEpi              | 26
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 18513305
#  casosNovos             | 64903
#  obitosAcumulado        | 515985
#  obitosNovos            | 1893
#  Recuperadosnovos       | 16779136
#  emAcompanhamentoNovos  | 1218184
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 181--------------------------
#  regiao                 | Brasil
#  estado                 | null
#  coduf                  | 76
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-06-30
#  semanaEpi              | 26
#  populacaoTCU2019       | 210147125
#  casosAcumulado         | 18557141
#  casosNovos             | 43836
#  obitosAcumulado        | 518066
#  obitosNovos            | 2081
#  Recuperadosnovos       | 16858632
#  emAcompanhamentoNovos  | 1180443
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 182--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-01
#  semanaEpi              | 53
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 95999
#  casosNovos             | 270
#  obitosAcumulado        | 1822
#  obitosNovos            | 5
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 183--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-02
#  semanaEpi              | 53
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 96433
#  casosNovos             | 434
#  obitosAcumulado        | 1825
#  obitosNovos            | 3
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 184--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-03
#  semanaEpi              | 1
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 96906
#  casosNovos             | 473
#  obitosAcumulado        | 1832
#  obitosNovos            | 7
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 185--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-04
#  semanaEpi              | 1
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 97197
#  casosNovos             | 291
#  obitosAcumulado        | 1840
#  obitosNovos            | 8
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 186--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-05
#  semanaEpi              | 1
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 97854
#  casosNovos             | 657
#  obitosAcumulado        | 1852
#  obitosNovos            | 12
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 187--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-06
#  semanaEpi              | 1
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 98811
#  casosNovos             | 957
#  obitosAcumulado        | 1875
#  obitosNovos            | 23
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 188--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-07
#  semanaEpi              | 1
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 99595
#  casosNovos             | 784
#  obitosAcumulado        | 1890
#  obitosNovos            | 15
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 189--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-08
#  semanaEpi              | 1
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 100343
#  casosNovos             | 748
#  obitosAcumulado        | 1899
#  obitosNovos            | 9
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 190--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-09
#  semanaEpi              | 1
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 101024
#  casosNovos             | 681
#  obitosAcumulado        | 1908
#  obitosNovos            | 9
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 191--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-10
#  semanaEpi              | 2
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 101588
#  casosNovos             | 564
#  obitosAcumulado        | 1911
#  obitosNovos            | 3
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 192--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-11
#  semanaEpi              | 2
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 102518
#  casosNovos             | 930
#  obitosAcumulado        | 1926
#  obitosNovos            | 15
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 193--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-12
#  semanaEpi              | 2
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 103798
#  casosNovos             | 1280
#  obitosAcumulado        | 1950
#  obitosNovos            | 24
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 194--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-13
#  semanaEpi              | 2
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 104737
#  casosNovos             | 939
#  obitosAcumulado        | 1965
#  obitosNovos            | 15
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 195--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-14
#  semanaEpi              | 2
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 105952
#  casosNovos             | 1215
#  obitosAcumulado        | 1976
#  obitosNovos            | 11
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 196--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-15
#  semanaEpi              | 2
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 107332
#  casosNovos             | 1380
#  obitosAcumulado        | 1993
#  obitosNovos            | 17
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 197--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-16
#  semanaEpi              | 2
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 108173
#  casosNovos             | 841
#  obitosAcumulado        | 1999
#  obitosNovos            | 6
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 198--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-17
#  semanaEpi              | 3
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 109056
#  casosNovos             | 883
#  obitosAcumulado        | 2005
#  obitosNovos            | 6
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# -RECORD 199--------------------------
#  regiao                 | Norte
#  estado                 | RO
#  coduf                  | 11
#  codmun                 | null
#  codRegiaoSaude         | null
#  nomeRegiaoSaude        | null
#  data                   | 2021-01-18
#  semanaEpi              | 3
#  populacaoTCU2019       | 1777225
#  casosAcumulado         | 110331
#  casosNovos             | 1275
#  obitosAcumulado        | 2031
#  obitosNovos            | 26
#  Recuperadosnovos       | null
#  emAcompanhamentoNovos  | null
#  interior/metropolitana | null
#  municipio              | null
# only showing top 200 rows

# %%
# VISUALIZAÇÃO 1 | Obitos estados do maior para o menor -> 1º Semestre 2021 (01/01/2021 - 30/06/2021)
estado_obitos = spark.sql("SELECT estado, MAX(obitosAcumulado) AS obitos FROM municipio WHERE estado IS NOT NULL GROUP BY estado ORDER BY obitos DESC")
estado_obitos.show()
# Out:
# +------+------+
# |estado|obitos|
# +------+------+
# |    SP|130389|
# |    RJ| 56192|
# |    MG| 47148|
# |    RS| 31867|
# |    PR| 31692|
# |    BA| 24428|
# |    CE| 22791|
# |    GO| 19485|
# |    PE| 17953|
# |    SC| 17146|
# |    PA| 15624|
# |    AM| 13349|
# |    MT| 12000|
# |    ES| 11582|
# |    DF|  9322|
# |    MA|  9190|
# |    PB|  8724|
# |    MS|  8400|
# |    RN|  6853|
# |    PI|  6662|
# +------+------+
# only showing top 20 rows

# %%
# VISUALIZAÇÃO 1.1 | Óbitos pelas regiões do Brasil e Brasil como um todo. ( Brasil inicia o ano de 2021 com 195.411 óbitos )
regiao_br_obitos = spark.sql("select regiao, max(obitosAcumulado) as obitos from municipio group by regiao order by obitos desc")
regiao_br_obitos.show()
# Out:
# +------------+------+
# |      regiao|obitos|
# +------------+------+
# |      Brasil|526892|
# |     Sudeste|130389|
# |         Sul| 31867|
# |    Nordeste| 24428|
# |Centro-Oeste| 19485|
# |       Norte| 15624|
# +------------+------+

# %%
# VISUALIZAÇÃO 2 | Número total de casos novos no fim do primeiro semestre de 2021.
casos_novos = spark.sql("SELECT estado, sum(casosNovos) AS casos_novos FROM municipio where estado IS NOT NULL group by estado order by casos_novos desc")
casos_novos.show()
# Out:
# +------+-----------+
# |estado|casos_novos|
# +------+-----------+
# |    SP|    4693850|
# |    MG|    2586578|
# |    PR|    1784154|
# |    RS|    1572480|
# |    BA|    1296424|
# |    SC|    1147802|
# |    CE|    1119174|
# |    RJ|    1071240|
# |    GO|     755130|
# |    PE|     678678|
# |    MT|     553456|
# |    ES|     549766|
# |    PA|     528336|
# |    PB|     471382|
# |    RN|     458330|
# |    MS|     411124|
# |    AM|     408106|
# |    DF|     366014|
# |    PI|     312824|
# |    RO|     312496|
# +------+-----------+
# only showing top 20 rows

# %%
# Visualizaçaõ 3 | Valor médio de casos novos e óbitos diários no primeiro semestre por estado.
casos_obitos_media = spark.sql("SELECT estado, ROUND(SUM(casosNovos) / COUNT(data),2) AS media_casos_novos , ROUND(AVG(obitosAcumulado),2) AS media_obitos_diarios FROM municipio WHERE estado IS NOT NULL GROUP BY estado ORDER BY media_casos_novos DESC")
casos_obitos_media.show()
# Out:
# +------+-----------------+--------------------+
# |estado|media_casos_novos|media_obitos_diarios|
# +------+-----------------+--------------------+
# |    DF|           978.65|             6551.88|
# |    RJ|            60.94|              847.68|
# |    SP|             38.8|              253.57|
# |    ES|            36.75|              204.69|
# |    AM|            34.64|              352.01|
# |    CE|            32.18|              164.61|
# |    AP|            31.37|              161.49|
# |    RO|            30.95|              152.26|
# |    RR|            28.35|              153.21|
# |    MS|            27.48|              121.27|
# |    PR|            23.79|                91.4|
# |    SE|             21.4|              100.22|
# |    MT|             20.7|              111.37|
# |    SC|            20.67|               74.01|
# |    AC|            20.64|               112.0|
# |    PA|            19.49|               152.9|
# |    PE|            19.41|              139.33|
# |    RS|            16.85|               79.49|
# |    BA|            16.55|               75.92|
# |    GO|            16.28|               99.67|
# +------+-----------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### Após as 3 visualizações criadas, salvei a 1º como tabela HIVE

# %%
estado_obitos.write.format('csv').saveAsTable('Obitos_por_estado')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o87.saveAsTable.
# : org.apache.spark.sql.AnalysisException: Table `Obitos_por_estado` already exists.;
# 	at org.apache.spark.sql.DataFrameWriter.saveAsTable(DataFrameWriter.scala:415)
# 	at org.apache.spark.sql.DataFrameWriter.saveAsTable(DataFrameWriter.scala:400)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-15-392cf090db7c> in <module>()
# ----> 1 estado_obitos.write.format('csv').saveAsTable('Obitos_por_estado')
#
# /opt/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#     773         if format is not None:
#     774             self.format(format)
# --> 775         self._jwrite.saveAsTable(name)
#     776
#     777     @since(1.4)
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'Table `Obitos_por_estado` already exists.;'

# %%
regiao_br_obitos.write.format('csv').saveAsTable('Obitos_por_regiao')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o93.saveAsTable.
# : org.apache.spark.sql.AnalysisException: Table `Obitos_por_regiao` already exists.;
# 	at org.apache.spark.sql.DataFrameWriter.saveAsTable(DataFrameWriter.scala:415)
# 	at org.apache.spark.sql.DataFrameWriter.saveAsTable(DataFrameWriter.scala:400)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-14-e797acae0ba1> in <module>()
# ----> 1 regiao_br_obitos.write.format('csv').saveAsTable('Obitos_por_regiao')
#
# /opt/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#     773         if format is not None:
#     774             self.format(format)
# --> 775         self._jwrite.saveAsTable(name)
#     776
#     777     @since(1.4)
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'Table `Obitos_por_regiao` already exists.;'

# %%
#Visualizar as tabelas salvas 
spark.sql('SHOW TABLES').show()
# Out:
# +--------+-----------------+-----------+
# |database|        tableName|isTemporary|
# +--------+-----------------+-----------+
# |   covid|        municipio|      false|
# |   covid|obitos_por_estado|      false|
# |   covid|obitos_por_regiao|      false|
# +--------+-----------------+-----------+

# %% [markdown]
# #### A 2ª com formato parquet e compressão snappy

# %%
casos_novos.write.option('compression', 'snappy').parquet('/user/spark/projeto_final_basico/segunda_visualizacao')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o121.parquet.
# : org.apache.spark.sql.AnalysisException: path hdfs://namenode:8020/user/spark/projeto_final_basico/segunda_visualizacao already exists.;
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:114)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:104)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:102)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.doExecute(commands.scala:122)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:131)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:155)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:152)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:80)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:80)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:668)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:668)
# 	at org.apache.spark.sql.execution.SQLExecution$$anonfun$withNewExecutionId$1.apply(SQLExecution.scala:78)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:125)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:73)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:668)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:276)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:270)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:228)
# 	at org.apache.spark.sql.DataFrameWriter.parquet(DataFrameWriter.scala:557)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-18-812a92f25416> in <module>()
# ----> 1 casos_novos.write.option('compression', 'snappy').parquet('/user/spark/projeto_final_basico/segunda_visualizacao')
#
# /opt/spark/python/pyspark/sql/readwriter.py in parquet(self, path, mode, partitionBy, compression)
#     839             self.partitionBy(partitionBy)
#     840         self._set_opts(compression=compression)
# --> 841         self._jwrite.parquet(path)
#     842
#     843     @since(1.6)
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'path hdfs://namenode:8020/user/spark/projeto_final_basico/segunda_visualizacao already exists.;'

# %%
#Conferindo se foi salvo corretamente
# !hdfs dfs -ls '/user/spark/projeto_final_basico/segunda_visualizacao'
# Out:
# Found 28 items
# -rw-r--r--   2 root supergroup          0 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/_SUCCESS
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00000-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00001-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00002-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00003-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00004-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00005-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00006-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00007-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00008-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00009-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00010-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00011-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00012-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00013-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00014-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00015-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00016-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00017-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00018-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00019-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00020-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00021-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00022-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00023-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00024-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00025-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet
# -rw-r--r--   2 root supergroup        650 2022-12-10 19:46 /user/spark/projeto_final_basico/segunda_visualizacao/part-00026-4973fb5e-6e20-4589-bf5c-e2b01f12a3aa-c000.snappy.parquet

# %% [markdown]
# #### A 3ª em um tópico no Kafka

# %%
casos_obitos_media.selectExpr("to_json(struct(*)) AS value").write.format('kafka').option('kafka.bootstrap.servers', 'kafka:9092').option('topic', 'casos_obitos_media').save()

# %%
topic = spark.read.format('kafka').option('kafka.bootstrap.servers', 'kafka:9092').option('subscribe','casos_obitos_media').load()

topic_media_casos_obitos = topic.select(col('value').cast('string'))
topic_media_casos_obitos.show(truncate = False)
# Out:
# +-------------------------------------------------------------------------+
# |value                                                                    |
# +-------------------------------------------------------------------------+
# |{"estado":"ES","media_casos_novos":36.75,"media_obitos_diarios":204.69}  |
# |{"estado":"SP","media_casos_novos":38.8,"media_obitos_diarios":253.57}   |
# |{"estado":"DF","media_casos_novos":978.65,"media_obitos_diarios":6551.88}|
# |{"estado":"RJ","media_casos_novos":60.94,"media_obitos_diarios":847.68}  |
# |{"estado":"AP","media_casos_novos":31.37,"media_obitos_diarios":161.49}  |
# |{"estado":"AM","media_casos_novos":34.64,"media_obitos_diarios":352.01}  |
# |{"estado":"RO","media_casos_novos":30.95,"media_obitos_diarios":152.26}  |
# |{"estado":"CE","media_casos_novos":32.18,"media_obitos_diarios":164.61}  |
# |{"estado":"MS","media_casos_novos":27.48,"media_obitos_diarios":121.27}  |
# |{"estado":"PR","media_casos_novos":23.79,"media_obitos_diarios":91.4}    |
# |{"estado":"RR","media_casos_novos":28.35,"media_obitos_diarios":153.21}  |
# |{"estado":"SE","media_casos_novos":21.4,"media_obitos_diarios":100.22}   |
# |{"estado":"MT","media_casos_novos":20.7,"media_obitos_diarios":111.37}   |
# |{"estado":"SC","media_casos_novos":20.67,"media_obitos_diarios":74.01}   |
# |{"estado":"AC","media_casos_novos":20.64,"media_obitos_diarios":112.0}   |
# |{"estado":"PA","media_casos_novos":19.49,"media_obitos_diarios":152.9}   |
# |{"estado":"PE","media_casos_novos":19.41,"media_obitos_diarios":139.33}  |
# |{"estado":"BA","media_casos_novos":16.55,"media_obitos_diarios":75.92}   |
# |{"estado":"RS","media_casos_novos":16.85,"media_obitos_diarios":79.49}   |
# |{"estado":"MG","media_casos_novos":16.18,"media_obitos_diarios":64.54}   |
# +-------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# #### Agora criei uma visualização geral no Spark com todos os dados enviados para o HDFS : Síntese de casos, óbitos, incidência e mortalidade
#
# ##### Não consegui criar com SQL Querys

# %%
df_geral = csv_df.groupBy(['regiao', 'estado']).agg({'casosAcumulado':'max', 'obitosAcumulado':'max', 'populacaoTCU2019':'max'})

# %%
df_geral.show(10)
# Out:
# +--------+------+---------------------+-------------------+--------------------+
# |  regiao|estado|max(populacaoTCU2019)|max(casosAcumulado)|max(obitosAcumulado)|
# +--------+------+---------------------+-------------------+--------------------+
# |   Norte|    TO|              1572866|             200243|                3266|
# |   Norte|    AC|               881935|              85997|                1760|
# |   Norte|    PA|              8602865|             557708|               15624|
# |Nordeste|    MA|              7075181|             322052|                9190|
# |     Sul|    RS|             11377239|            1235914|               31867|
# | Sudeste|    SP|             45919049|            3809222|              130389|
# |Nordeste|    PI|              3273227|             299084|                6662|
# |   Norte|    AP|               845731|             118066|                1857|
# | Sudeste|    MG|             21168791|            1836198|               47148|
# |     Sul|    PR|             11433957|            1308643|               31692|
# +--------+------+---------------------+-------------------+--------------------+
# only showing top 10 rows

# %%
df_renomear_campos = df_geral.withColumnRenamed('max(populacaoTCU2019)','populacao').withColumnRenamed('max(casosAcumulado)', 'casos_acumulados').withColumnRenamed('max(obitosAcumulado)','obitos_acumulados')

# %%
df_geral_completo = (df_renomear_campos.withColumn('incidencia', round(df_renomear_campos['casos_acumulados']/df_renomear_campos['populacao']*100000,1)).withColumn('mortalidade', round(df_renomear_campos['obitos_acumulados']/df_renomear_campos['populacao']*100000,1)))

# %%
df_geral_completo.show(10)
# Out:
# +--------+------+---------+----------------+-----------------+----------+-----------+
# |  regiao|estado|populacao|casos_acumulados|obitos_acumulados|incidencia|mortalidade|
# +--------+------+---------+----------------+-----------------+----------+-----------+
# |   Norte|    TO|  1572866|          200243|             3266|   12731.1|      207.6|
# |   Norte|    AC|   881935|           85997|             1760|    9750.9|      199.6|
# |   Norte|    PA|  8602865|          557708|            15624|    6482.8|      181.6|
# |Nordeste|    MA|  7075181|          322052|             9190|    4551.9|      129.9|
# |     Sul|    RS| 11377239|         1235914|            31867|   10863.0|      280.1|
# | Sudeste|    SP| 45919049|         3809222|           130389|    8295.5|      284.0|
# |Nordeste|    PI|  3273227|          299084|             6662|    9137.3|      203.5|
# |   Norte|    AP|   845731|          118066|             1857|   13960.2|      219.6|
# | Sudeste|    MG| 21168791|         1836198|            47148|    8674.1|      222.7|
# |     Sul|    PR| 11433957|         1308643|            31692|   11445.2|      277.2|
# +--------+------+---------+----------------+-----------------+----------+-----------+
# only showing top 10 rows

# %% [markdown]
# #### Salvar a visualização do exercício 6 em um tópico no Elastic

# %%
df_final = topic_media_casos_obitos
df_final.write.format("csv").save('hdfs://namenode/user/spark/projeto_final_basico/visualizacao3/covid_elastic.csv')

# %%
# !hdfs dfs -ls /user/spark/projeto_final_basico/visualizacao3/covid_elastic.csv
# Out:
# Found 2 items
# -rw-r--r--   2 root supergroup          0 2022-12-11 21:06 /user/spark/projeto_final_basico/visualizacao3/covid_elastic.csv/_SUCCESS
# -rw-r--r--   2 root supergroup      13152 2022-12-11 21:06 /user/spark/projeto_final_basico/visualizacao3/covid_elastic.csv/part-00000-0e0c2620-4d94-4828-b4b0-a6cf95193708-c000.csv

# %%
# !hdfs dfs -get /user/spark/projeto_final_basico/visualizacao3/covid_elastic.csv /input
